# %%
from ultralytics import YOLO

model = YOLO(model="yolov8m.pt")

results = model("images/people3.jpg", device="cuda", conf=0.5, iou=0.7, classes=[0])
results[0].show()
# Out:
# image 1/1 z:\ML\Projects\Computer-Vision-projects\yolo-people-counter\images\people3.jpg: 448x640 7 persons, 26.7ms
# Speed: 1.5ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.predict(source=0, show=True)  # 0 = default webcam
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 9.7ms
# 0: 480x640 (no detections), 9.7ms
# WARNING Waiting for stream 0
# 0: 480x640 1 cat, 9.6ms
# 0: 480x640 1 cat, 9.3ms
# 0: 480x640 (no detections), 18.0ms
# 0: 480x640 (no detections), 8.9ms
# WARNING Waiting for stream 0
# 0: 480x640 (no detections), 8.5ms
# WARNING Waiting for stream 0
# 0: 480x640 (no detections), 9.4ms
# ...

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8m.pt")
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    # Flip frame BEFORE detection
    frame = cv2.flip(frame, 1)
    
    # Run YOLO on flipped frame
    results = model(frame, conf=0.5, iou=0.7)
    
    # Draw boxes (text will be correct now)
    annotated_frame = results[0].plot()
    
    cv2.imshow("YOLO Detection", annotated_frame)
    
    if cv2.waitKey(1) & 0xFF == ord("e"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 526.5ms
# Speed: 1.5ms preprocess, 526.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.6ms
# Speed: 1.1ms preprocess, 19.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.8ms
# Speed: 1.5ms preprocess, 22.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.8ms
# Speed: 1.3ms preprocess, 19.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.9ms
# Speed: 1.8ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.2ms
# Speed: 2.4ms preprocess, 20.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.4ms
# ...
